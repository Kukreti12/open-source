# %%
# SPDX-FileCopyrightText: Copyright (c) 2022 NVIDIA CORPORATION & AFFILIATES. All rights reserved.
# SPDX-License-Identifier: MIT

# %% [markdown]
# # ASR API tutorial
#
# This tutorial demonstates how to use Python Riva API.
#
# ## <font color="blue">Server</font>
#
# Before running client part of Riva, please set up a server. The simplest
# way to do this is to follow
# [quick start guide](https://docs.nvidia.com/deeplearning/riva/user-guide/docs/quick-start-guide.html#local-deployment-using-quick-start-scripts).
#
#
# ## <font color="blue">Authentication</font>
#
# Before using Riva services you will need to establish connection with a server.

# %%
import riva.client

uri = "10.10.162.12:50051"  # Default value

auth = riva.client.Auth(uri=uri)

# %% [markdown]
# ## <font color="blue">Setting up service</font>
#
# To instantiate a service pass `riva.client.Auth` instance to a constructor.

# %%
asr_service = riva.client.ASRService(auth)

# %% [markdown]
# For speech recognition you will need to create a recognition config (an instance of `riva.client.RecognitionConfig`).
# A detailed description of config fields is available in Riva
# [documentation](https://docs.nvidia.com/deeplearning/riva/user-guide/docs/reference/protos/riva_asr.proto.html?highlight=max%20alternatives#riva-proto-riva-asr-proto).
# If you intend to use streaming recognition, an offline config has to wrapped into `riva.client.StreamingRecognitionConfig`.

# %%
from copy import deepcopy
offline_config = riva.client.RecognitionConfig(
    encoding=riva.client.AudioEncoding.LINEAR_PCM,
    max_alternatives=1,
    enable_automatic_punctuation=True,
    verbatim_transcripts=False,
)
streaming_config = riva.client.StreamingRecognitionConfig(config=deepcopy(offline_config), interim_results=True)

# %% [markdown]
# You also need to a set frame rate and number of channels of audio which is going to be processed. If you'd like to process file `data/examples/en-US_AntiBERTa_for_word_boosting_testing.wav`, then your code will be

# %%
my_wav_file = 'mono.wav'
riva.client.add_audio_file_specs_to_config(offline_config, my_wav_file)
riva.client.add_audio_file_specs_to_config(streaming_config, my_wav_file)

# %% [markdown]
# If you intent to use word boosting, then use convenience method `riva.client.add_word_boosting_to_config()` to add boosting parameters to config.

# %%
boosted_lm_words = ['AntiBERTa', 'ABlooper']
boosted_lm_score = 20.0
riva.client.add_word_boosting_to_config(offline_config, boosted_lm_words, boosted_lm_score)
riva.client.add_word_boosting_to_config(streaming_config, boosted_lm_words, boosted_lm_score)

# %%
print(offline_config)
# Out:
# encoding: LINEAR_PCM
# sample_rate_hertz: 44100
# max_alternatives: 1
# speech_contexts {
#   phrases: "AntiBERTa"
#   phrases: "ABlooper"
#   boost: 20
# }
# audio_channel_count: 1
# enable_automatic_punctuation: true

# %%
print(streaming_config)
# Out:
# config {
#   encoding: LINEAR_PCM
#   sample_rate_hertz: 44100
#   max_alternatives: 1
#   speech_contexts {
#     phrases: "AntiBERTa"
#     phrases: "ABlooper"
#     boost: 20
#   }
#   audio_channel_count: 1
#   enable_automatic_punctuation: true
# }
# interim_results: true

# %% [markdown]
# ## <font color="blue">Offline</font>
#
# To run offline speech recognition read data from a file and pass to a service.

# %%
with open(my_wav_file, 'rb') as fh:
    data = fh.read()

# %%
response = asr_service.offline_recognize(data, offline_config)

# %%
print(response)
# Out:
# results {
#   alternatives {
#     transcript: "The stale smell of old beer lingers. "
#     confidence: -2.30204725
#   }
#   channel_tag: 1
#   audio_processed: 4.8
# }
# results {
#   alternatives {
#     transcript: "It takes heat to bring out the odor. "
#     confidence: -1.76582098
#   }
#   channel_tag: 1
#   audio_processed: 9.6
# }
# results {
#   alternatives {
#     transcript: "A cold dip restores Health and zest a salt pickle tastes fine with ham tacos al pastor are my favorite a zest ful food is the hot cross bun. "
#     confidence: -2.43338275
#   }
#   channel_tag: 1
#   audio_processed: 19.2
# }

# %% [markdown]
# To extract a transcript you may use

# %%
print(response.results[1].alternatives[0].transcript)
# Out:
# It takes heat to bring out the odor.

# %%
print(response.results[0].alternatives[0].confidence)
# Out:
# -2.3020472526550293

# %% [markdown]
# ### <font color="green">Asynchronous calls</font>
#
# You can recognize speech asynchronously by setting `future=True` in `ASRService.offline_recognize()`.

# %%
from time import time

num_repeats = 10

# %%
sync_transcripts = []
start_time = time()
for _ in range(num_repeats):
    sync_transcripts.append(
        asr_service.offline_recognize(data, offline_config).results[0].alternatives[0].transcript
    )
print(f"Time spent on synchronous recognition: {time() - start_time:.2f}")
# Out:
# Time spent on synchronous recognition: 30.67

# %%
async_transcripts = []
start_time = time()
futures = []
for _ in range(num_repeats):
    futures.append(asr_service.offline_recognize(data, offline_config, future=True))
for f in futures:
    async_transcripts.append(f.result().results[0].alternatives[0].transcript)
print(f"Time spent on async recognition: {time() - start_time:.2f}")
# Out:
# Time spent on async recognition: 20.83

# %%
assert sync_transcripts == async_transcripts

# %% [markdown]
# ## <font color="blue">Streaming</font>
#
# To imitate audio streaming use `riva.client.AudioChunkFileIterator`. You can imitate realtime audio by providing a delay callback to the iterator.

# %%
wav_parameters = riva.client.get_wav_file_parameters(my_wav_file)
# correponds to 1 second of audio
chunk_size = wav_parameters['framerate']
with riva.client.AudioChunkFileIterator(
    my_wav_file, chunk_size, delay_callback=riva.client.sleep_audio_length,
) as audio_chunk_iterator:
    for i, chunk in enumerate(audio_chunk_iterator):
        print(i, len(chunk))
# Out:
# 0 88200
# 1 88200
# 2 88200
# 3 88200
# 4 88200
# 5 88200
# 6 88200
# 7 88200
# 8 88200
# 9 88200
# 10 88200
# 11 88200
# 12 88200
# 13 88200
# 14 88200
# 15 88200
# 16 88200
# 17 88200
# 18 31514

# %% [markdown]
# Then audio chunks are passed to `ASRService.streaming_response_generator()` and response generator is created.

# %%
audio_chunk_iterator = riva.client.AudioChunkFileIterator(my_wav_file, 4800)
response_generator = asr_service.streaming_response_generator(audio_chunk_iterator, streaming_config)

# %% [markdown]
# You may find description of streaming response (`StreamingRecognizeResponse`) fields in Riva [documentation](https://docs.nvidia.com/deeplearning/riva/user-guide/docs/reference/protos/riva_asr.proto.html?highlight=max%20alternatives#riva-proto-riva-asr-proto).

# %%
streaming_response = next(response_generator)

# %% [markdown]
# For showing streaming results it is convenient to use function `riva.client.print_streaming()`.

# %%
riva.client.print_streaming(response_generator, additional_info='time')
# Out:
# >>>Time 1693326570.47s: this
# >>>Time 1693326570.47s: the state
# >>>Time 1693326570.47s: the
# >>>Time 1693326570.47s: the salesman
# >>>Time 1693326570.47s: the stale smell
# >>>Time 1693326570.47s: the stale smell of
# >>>Time 1693326570.47s: the stale smell of
# >>>Time 1693326570.47s: the stale smell of old
# >>>Time 1693326570.47s: the stale smell of
# >>>Time 1693326570.47s: the stale smell of old beer
# >>>Time 1693326570.47s: the stale smell of old beer
# >>>Time 1693326570.47s: stale smell of old beer lingered
# >>>Time 1693326570.47s: the stale smell of old beer lingers
# >>>Time 1693326570.47s: the smell of old beer lingers
# >>>Time 1693326570.47s: the smell of old beer lingers
# >>>Time 1693326570.47s: the stale mell of old beer lingers
# >>>Time 1693326570.47s: the stale of old beer lingers
# >>>Time 1693326570.47s: the stale of old beer lingers
# Time 0.00s: Transcript 0: The stale smell of old beer lingers.
# >>>Time 1693326570.47s: it takes
# >>>Time 1693326570.47s: it takes
# >>>Time 1693326570.47s: it takes
# >>>Time 1693326570.47s: it takes heat
# >>>Time 1693326570.47s: it takes heat
# >>>Time 1693326570.47s: it takes heat to
# >>>Time 1693326570.47s: it takes heat to bring
# >>>Time 1693326570.47s: it takes heat to bring out
# >>>Time 1693326570.47s: it takes heat to bring out the
# >>>Time 1693326570.47s: it takes heat to bring out the ocean
# >>>Time 1693326570.47s: it takes heat to bring out the odor
# >>>Time 1693326570.47s: it takes heat to bring out the odor
# >>>Time 1693326570.47s: it heat to bring out the odor
# >>>Time 1693326570.47s: it heat to bring out the odor
# >>>Time 1693326570.47s: it heat to bring out the odor
# >>>Time 1693326570.47s: it takes to bring out the odor
# >>>Time 1693326570.47s: it takes to bring out the odor it
# >>>Time 1693326570.47s: it takes heat to bring out the odor a coal
# Time 0.01s: Transcript 0: It takes heat to bring out the odor.
# >>>Time 1693326570.47s: a cold
# >>>Time 1693326570.47s: a cold dip
# >>>Time 1693326570.47s: a cold dip
# >>>Time 1693326570.47s: a cold dip
# >>>Time 1693326570.48s: a cold dip
# >>>Time 1693326570.48s: a cold dip restores
# >>>Time 1693326570.48s: a cold dip restores
# >>>Time 1693326570.48s: a cold dip restores Health
# >>>Time 1693326570.48s: a cold dip restores Health
# >>>Time 1693326570.48s: a cold dip restores Health and
# >>>Time 1693326570.48s: a cold dip restores Health
# >>>Time 1693326570.48s: a dip restores Health and zest
# >>>Time 1693326570.48s: a dip restores Health and zest
# >>>Time 1693326570.48s: a cold restores Health and zest
# >>>Time 1693326570.48s: a cold restores Health and zest
# >>>Time 1693326570.48s: a cold restores Health and zest
# >>>Time 1693326570.48s: a cold dip stores Health and zest
# >>>Time 1693326570.48s: a cold dip Health and zest a
# >>>Time 1693326570.48s: a cold dip Health and zest a salt
# >>>Time 1693326570.48s: a cold dip restores and zest a salt
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pick
# >>>Time 1693326570.48s: a cold dip restores Health zest a salt pickle
# >>>Time 1693326570.48s: a cold dip restores Health and a salt pickled
# >>>Time 1693326570.48s: a cold dip restores Health and a salt pickle tastes
# >>>Time 1693326570.48s: a cold dip restores Health and a salt pickle tastes
# >>>Time 1693326570.48s: a cold dip restores Health and a salt pickle tastes fine
# >>>Time 1693326570.48s: a cold dip restores Health and a salt pickle tastes fine with
# >>>Time 1693326570.48s: a cold dip restores Health and a salt pickle tastes fine with
# >>>Time 1693326570.48s: a cold dip restores Health and zest salt pickle tastes fine with ham
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle tastes fine with ham
# >>>Time 1693326570.48s: a cold dip restores Health and zest a pickle tastes fine with ham
# >>>Time 1693326570.48s: a cold dip restores Health and zest a pickle tastes fine with ham
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt cole tastes fine with ham
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt taste fine with ham tuck
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt tastes fine with ham tacos
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle fine with ham tacos
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle fine with ham tacos all
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste with ham tacos past
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste with ham tacos pastor
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos pastor
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with tacos al pastor are my
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with tacos al pastor are my favorite
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with tacos al pastor are my favorite
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with tacos al pastor are my favorite
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with tacos al pastor are my favorite
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham cos al pastor are my favorite
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham al pastor are my favorite
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos pastor are my favorite
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al stor are my favorite
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al are my favorite a zest
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor my favorite a zestfully
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor my favorite a
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are favorite a zest ful food
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my ite a
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my a zest
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite a zest fuloos
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite a zest fuloos the
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite a zest fuloos
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite a zest fuloos the hot
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite zest fuloos the hot cross
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a ful food is the hot cross
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a ful food is the hot cross bun
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a food is the hot cross bun
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a fod is the hot cross bun
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful is the hot cross bun
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful is the hot cross bun
# >>>Time 1693326570.48s: a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful is the hot cross bun
# Time 0.01s: Transcript 0: A cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful food is the hot cross bun.

# %% [markdown]
# If you set a delay callback in audio chunk iterator and `show_intermediate=True` in `riva.client.print_streaming()`, then you will be able watch transcript forming.

# %%
audio_chunk_iterator = riva.client.AudioChunkFileIterator(my_wav_file, 4800, riva.client.sleep_audio_length)
response_generator = asr_service.streaming_response_generator(audio_chunk_iterator, streaming_config)
riva.client.print_streaming(response_generator, show_intermediate=True)
# Out:
# ## The stale smell of old beer lingers.
# ## It takes heat to bring out the odor.
# ## A cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful food is the hot cross bun.

# %% [markdown]
# It is also possible to print streaming results in several places, e.g. in STDOUT and a file.

# %%
import sys
output_file = "my_results.txt"
audio_chunk_iterator = riva.client.AudioChunkFileIterator(my_wav_file, 4800)
response_generator = asr_service.streaming_response_generator(audio_chunk_iterator, streaming_config)
riva.client.print_streaming(response_generator, additional_info='confidence', output_file=[sys.stdout, output_file])
# Out:
# >> this
# Stability:    0.1000
# ----
# >> the state
# Stability:    0.1000
# ----
# >> the
# Stability:    0.1000
# ----
# >> the salesman
# Stability:    0.1000
# ----
# >> the stale smell
# Stability:    0.1000
# ----
# >> the stale smell of
# Stability:    0.1000
# ----
# >> the stale smell of
# Stability:    0.1000
# ----
# >> the stale smell of old
# Stability:    0.1000
# ----
# >> the stale smell of
# Stability:    0.1000
# ----
# >> the stale smell of old beer
# Stability:    0.1000
# ----
# >> the stale smell of old beer
# Stability:    0.1000
# ----
# >> stale smell of old beer lingered
# Stability:    0.1000
# ----
# >> the
# Stability:    0.9000
# >> stale smell of old beer lingers
# Stability:    0.1000
# ----
# >> the
# Stability:    0.9000
# >> smell of old beer lingers
# Stability:    0.1000
# ----
# >> the
# Stability:    0.9000
# >> smell of old beer lingers
# Stability:    0.1000
# ----
# >> the stale
# Stability:    0.9000
# >> mell of old beer lingers
# Stability:    0.1000
# ----
# >> the stale
# Stability:    0.9000
# >> of old beer lingers
# Stability:    0.1000
# ----
# >> the stale
# Stability:    0.9000
# >> of old beer lingers
# Stability:    0.1000
# ----
# ## The stale smell of old beer lingers.
# Confidence:   -2.2790
# ----
# >> it takes
# Stability:    0.1000
# ----
# >> it takes
# Stability:    0.1000
# ----
# >> it takes
# Stability:    0.1000
# ----
# >> it takes heat
# Stability:    0.1000
# ----
# >> it takes heat
# Stability:    0.1000
# ----
# >> it takes heat to
# Stability:    0.1000
# ----
# >> it takes heat to bring
# Stability:    0.1000
# ----
# >> it takes heat to bring out
# Stability:    0.1000
# ----
# >> it takes heat to bring out the
# Stability:    0.1000
# ----
# >> it takes heat to bring out the ocean
# Stability:    0.1000
# ----
# >> it takes heat to bring out the odor
# Stability:    0.1000
# ----
# >> it
# Stability:    0.9000
# >> takes heat to bring out the odor
# Stability:    0.1000
# ----
# >> it
# Stability:    0.9000
# >> heat to bring out the odor
# Stability:    0.1000
# ----
# >> it
# Stability:    0.9000
# >> heat to bring out the odor
# Stability:    0.1000
# ----
# >> it
# Stability:    0.9000
# >> heat to bring out the odor
# Stability:    0.1000
# ----
# >> it takes
# Stability:    0.9000
# >> to bring out the odor
# Stability:    0.1000
# ----
# >> it takes
# Stability:    0.9000
# >> to bring out the odor it
# Stability:    0.1000
# ----
# >> it takes heat to
# Stability:    0.9000
# >> bring out the odor a coal
# Stability:    0.1000
# ----
# ## It takes heat to bring out the odor.
# Confidence:   -1.7659
# >> a cold
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.1000
# ----
# >> a cold dip restores
# Stability:    0.1000
# ----
# >> a cold dip restores
# Stability:    0.1000
# ----
# >> a cold dip restores Health
# Stability:    0.1000
# ----
# >> a cold dip restores Health
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.1000
# ----
# >> a
# Stability:    0.9000
# >> cold dip restores Health
# Stability:    0.1000
# ----
# >> a
# Stability:    0.9000
# >> dip restores Health and zest
# Stability:    0.1000
# ----
# >> a
# Stability:    0.9000
# >> dip restores Health and zest
# Stability:    0.1000
# ----
# >> a cold
# Stability:    0.9000
# >> restores Health and zest
# Stability:    0.1000
# ----
# >> a cold
# Stability:    0.9000
# >> restores Health and zest
# Stability:    0.1000
# ----
# >> a cold
# Stability:    0.9000
# >> restores Health and zest
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.9000
# >> stores Health and zest
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.9000
# >> Health and zest a
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.9000
# >> Health and zest a salt
# Stability:    0.1000
# ----
# >> a cold dip restores
# Stability:    0.9000
# >> and zest a salt
# Stability:    0.1000
# ----
# >> a cold dip restores Health
# Stability:    0.9000
# >> and zest a salt pick
# Stability:    0.1000
# ----
# >> a cold dip restores Health
# Stability:    0.9000
# >> zest a salt pickle
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickled
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickle tastes
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickle tastes
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickle tastes fine
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickle tastes fine with
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickle tastes fine with
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest
# Stability:    0.9000
# >> salt pickle tastes fine with ham
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a
# Stability:    0.9000
# >> salt pickle tastes fine with ham
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a
# Stability:    0.9000
# >> pickle tastes fine with ham
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a
# Stability:    0.9000
# >> pickle tastes fine with ham
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt
# Stability:    0.9000
# >> cole tastes fine with ham
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt
# Stability:    0.9000
# >> taste fine with ham tuck
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt
# Stability:    0.9000
# >> tastes fine with ham tacos
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle
# Stability:    0.9000
# >> fine with ham tacos
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle
# Stability:    0.9000
# >> fine with ham tacos all
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste
# Stability:    0.9000
# >> with ham tacos past
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste
# Stability:    0.9000
# >> with ham tacos pastor
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> ham tacos pastor
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> tacos al pastor are my
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> tacos al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> tacos al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> tacos al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> tacos al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham
# Stability:    0.9000
# >> cos al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham
# Stability:    0.9000
# >> al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos
# Stability:    0.9000
# >> pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al
# Stability:    0.9000
# >> pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al
# Stability:    0.9000
# >> stor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al
# Stability:    0.9000
# >> are my favorite a zest
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor
# Stability:    0.9000
# >> my favorite a zestfully
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor
# Stability:    0.9000
# >> my favorite a
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are
# Stability:    0.9000
# >> favorite a zest ful food
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my
# Stability:    0.9000
# >> ite a
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my
# Stability:    0.9000
# >> a zest
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite
# Stability:    0.9000
# >> a zest fuloos
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite
# Stability:    0.9000
# >> a zest fuloos the
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite
# Stability:    0.9000
# >> a zest fuloos
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite
# Stability:    0.9000
# >> a zest fuloos the hot
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite
# Stability:    0.9000
# >> zest fuloos the hot cross
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a
# Stability:    0.9000
# >> ful food is the hot cross
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a
# Stability:    0.9000
# >> ful food is the hot cross bun
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a
# Stability:    0.9000
# >> food is the hot cross bun
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a
# Stability:    0.9000
# >> fod is the hot cross bun
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful
# Stability:    0.9000
# >> is the hot cross bun
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful
# Stability:    0.9000
# >> is the hot cross bun
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful
# Stability:    0.9000
# >> is the hot cross bun
# Stability:    0.1000
# ----
# ## A cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful food is the hot cross bun.
# Confidence:   -2.4579
# ----

# %% [markdown]
# Showing file and clean up in bash

# %%
# !cat $output_file
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !rm $output_file
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# Showing file and clean up in cmd.exe

# %%
# !type $output_file
# Out:
# >> this
# Stability:    0.1000
# ----
# >> the state
# Stability:    0.1000
# ----
# >> the
# Stability:    0.1000
# ----
# >> the salesman
# Stability:    0.1000
# ----
# >> the stale smell
# Stability:    0.1000
# ----
# >> the stale smell of
# Stability:    0.1000
# ----
# >> the stale smell of
# Stability:    0.1000
# ----
# >> the stale smell of old
# Stability:    0.1000
# ----
# >> the stale smell of
# Stability:    0.1000
# ----
# >> the stale smell of old beer
# Stability:    0.1000
# ----
# >> the stale smell of old beer
# Stability:    0.1000
# ----
# >> stale smell of old beer lingered
# Stability:    0.1000
# ----
# >> the
# Stability:    0.9000
# >> stale smell of old beer lingers
# Stability:    0.1000
# ----
# >> the
# Stability:    0.9000
# >> smell of old beer lingers
# Stability:    0.1000
# ----
# >> the
# Stability:    0.9000
# >> smell of old beer lingers
# Stability:    0.1000
# ----
# >> the stale
# Stability:    0.9000
# >> mell of old beer lingers
# Stability:    0.1000
# ----
# >> the stale
# Stability:    0.9000
# >> of old beer lingers
# Stability:    0.1000
# ----
# >> the stale
# Stability:    0.9000
# >> of old beer lingers
# Stability:    0.1000
# ----
# ## The stale smell of old beer lingers.
# Confidence:   -2.2790
# ----
# >> it takes
# Stability:    0.1000
# ----
# >> it takes
# Stability:    0.1000
# ----
# >> it takes
# Stability:    0.1000
# ----
# >> it takes heat
# Stability:    0.1000
# ----
# >> it takes heat
# Stability:    0.1000
# ----
# >> it takes heat to
# Stability:    0.1000
# ----
# >> it takes heat to bring
# Stability:    0.1000
# ----
# >> it takes heat to bring out
# Stability:    0.1000
# ----
# >> it takes heat to bring out the
# Stability:    0.1000
# ----
# >> it takes heat to bring out the ocean
# Stability:    0.1000
# ----
# >> it takes heat to bring out the odor
# Stability:    0.1000
# ----
# >> it
# Stability:    0.9000
# >> takes heat to bring out the odor
# Stability:    0.1000
# ----
# >> it
# Stability:    0.9000
# >> heat to bring out the odor
# Stability:    0.1000
# ----
# >> it
# Stability:    0.9000
# >> heat to bring out the odor
# Stability:    0.1000
# ----
# >> it
# Stability:    0.9000
# >> heat to bring out the odor
# Stability:    0.1000
# ----
# >> it takes
# Stability:    0.9000
# >> to bring out the odor
# Stability:    0.1000
# ----
# >> it takes
# Stability:    0.9000
# >> to bring out the odor it
# Stability:    0.1000
# ----
# >> it takes heat to
# Stability:    0.9000
# >> bring out the odor a coal
# Stability:    0.1000
# ----
# ## It takes heat to bring out the odor.
# Confidence:   -1.7659
# >> a cold
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.1000
# ----
# >> a cold dip restores
# Stability:    0.1000
# ----
# >> a cold dip restores
# Stability:    0.1000
# ----
# >> a cold dip restores Health
# Stability:    0.1000
# ----
# >> a cold dip restores Health
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.1000
# ----
# >> a
# Stability:    0.9000
# >> cold dip restores Health
# Stability:    0.1000
# ----
# >> a
# Stability:    0.9000
# >> dip restores Health and zest
# Stability:    0.1000
# ----
# >> a
# Stability:    0.9000
# >> dip restores Health and zest
# Stability:    0.1000
# ----
# >> a cold
# Stability:    0.9000
# >> restores Health and zest
# Stability:    0.1000
# ----
# >> a cold
# Stability:    0.9000
# >> restores Health and zest
# Stability:    0.1000
# ----
# >> a cold
# Stability:    0.9000
# >> restores Health and zest
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.9000
# >> stores Health and zest
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.9000
# >> Health and zest a
# Stability:    0.1000
# ----
# >> a cold dip
# Stability:    0.9000
# >> Health and zest a salt
# Stability:    0.1000
# ----
# >> a cold dip restores
# Stability:    0.9000
# >> and zest a salt
# Stability:    0.1000
# ----
# >> a cold dip restores Health
# Stability:    0.9000
# >> and zest a salt pick
# Stability:    0.1000
# ----
# >> a cold dip restores Health
# Stability:    0.9000
# >> zest a salt pickle
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickled
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickle tastes
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickle tastes
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickle tastes fine
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickle tastes fine with
# Stability:    0.1000
# ----
# >> a cold dip restores Health and
# Stability:    0.9000
# >> a salt pickle tastes fine with
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest
# Stability:    0.9000
# >> salt pickle tastes fine with ham
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a
# Stability:    0.9000
# >> salt pickle tastes fine with ham
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a
# Stability:    0.9000
# >> pickle tastes fine with ham
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a
# Stability:    0.9000
# >> pickle tastes fine with ham
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt
# Stability:    0.9000
# >> cole tastes fine with ham
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt
# Stability:    0.9000
# >> taste fine with ham tuck
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt
# Stability:    0.9000
# >> tastes fine with ham tacos
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle
# Stability:    0.9000
# >> fine with ham tacos
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle
# Stability:    0.9000
# >> fine with ham tacos all
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste
# Stability:    0.9000
# >> with ham tacos past
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste
# Stability:    0.9000
# >> with ham tacos pastor
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> ham tacos pastor
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> tacos al pastor are my
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> tacos al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> tacos al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> tacos al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with
# Stability:    0.9000
# >> tacos al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham
# Stability:    0.9000
# >> cos al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham
# Stability:    0.9000
# >> al pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos
# Stability:    0.9000
# >> pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al
# Stability:    0.9000
# >> pastor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al
# Stability:    0.9000
# >> stor are my favorite
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al
# Stability:    0.9000
# >> are my favorite a zest
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor
# Stability:    0.9000
# >> my favorite a zestfully
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor
# Stability:    0.9000
# >> my favorite a
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are
# Stability:    0.9000
# >> favorite a zest ful food
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my
# Stability:    0.9000
# >> ite a
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my
# Stability:    0.9000
# >> a zest
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite
# Stability:    0.9000
# >> a zest fuloos
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite
# Stability:    0.9000
# >> a zest fuloos the
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite
# Stability:    0.9000
# >> a zest fuloos
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite
# Stability:    0.9000
# >> a zest fuloos the hot
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favorite
# Stability:    0.9000
# >> zest fuloos the hot cross
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a
# Stability:    0.9000
# >> ful food is the hot cross
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a
# Stability:    0.9000
# >> ful food is the hot cross bun
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a
# Stability:    0.9000
# >> food is the hot cross bun
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a
# Stability:    0.9000
# >> fod is the hot cross bun
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful
# Stability:    0.9000
# >> is the hot cross bun
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful
# Stability:    0.9000
# >> is the hot cross bun
# Stability:    0.1000
# ----
# >> a cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful
# Stability:    0.9000
# >> is the hot cross bun
# Stability:    0.1000
# ----
# ## A cold dip restores Health and zest a salt pickle taste fine with ham tacos al pastor are my favourite a zest ful food is the hot cross bun.
# Confidence:   -2.4579
# ----

# %%
# !del $output_file

# %% [markdown]
# ## <font color="blue">Audio input/output</font>
#
# For using audio input and output you need to install PyAudio.
#
# ```bash
# conda install -c anaconda pyaudio
# ```
#
# ### <font color="green">Playing audio during transcribing</font>
#
# For playing audio simultaneously with transcribing, provide an instance of `riva.client.audio_io.SoundCallBack` as a `delay_callback` to `riva.client.AudioChunkFileIterator`.

# %%
import pyaudio
import riva.client.audio_io

# %% [markdown]
# ### <font color="green">Streaming from microphone</font>

# %%
riva.client.audio_io.list_input_devices()
# Out:
# Input audio devices:
# 0: Microsoft Sound Mapper - Input
# 1: Microphone Array (Intel® Smart
# 5: Microphone (USB Audio)
# 9: PC Speaker (Realtek HD Audio output with SST)
# 10: Stereo Mix (Realtek HD Audio Stereo input)
# 11: Microphone (Realtek HD Audio Mic input)
# 14: PC Speaker (Realtek HD Audio 2nd output with SST)
# 15: Microphone Array 1 (Intel® Smart Sound Technology DMIC Microphone)
# 16: Microphone Array 2 (Intel® Smart Sound Technology DMIC Microphone)
# 17: Microphone Array 3 (Intel® Smart Sound Technology DMIC Microphone)
# 18: Microphone Array 4 (Intel® Smart Sound Technology DMIC Microphone)

# %% [markdown]
# Run code below and then say something in English

# %%
input_device = None  # default device
with riva.client.audio_io.MicrophoneStream(
    rate=streaming_config.config.sample_rate_hertz,
    chunk=streaming_config.config.sample_rate_hertz // 10,
    device=input_device,
) as audio_chunk_iterator:
    riva.client.print_streaming(
        responses=asr_service.streaming_response_generator(
            audio_chunks=audio_chunk_iterator,
            streaming_config=streaming_config,
        ),
        show_intermediate=True,
    )
# Out:
# ---------------------------------------------------------------------------
# _MultiThreadedRendezvous                  Traceback (most recent call last)
# Cell In[38], line 7
#       1 input_device = None  # default device
#       2 with riva.client.audio_io.MicrophoneStream(
#       3     rate=streaming_config.config.sample_rate_hertz,
#       4     chunk=streaming_config.config.sample_rate_hertz ,
#       5     device=input_device,
#       6 ) as audio_chunk_iterator:
# ----> 7     riva.client.print_streaming(
#       8         responses=asr_service.streaming_response_generator(
#       9             audio_chunks=audio_chunk_iterator,
#      10             streaming_config=streaming_config,
#      11         ),
#      12         show_intermediate=True,
#      13     )
#
# File c:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\riva\client\asr.py:197, in print_streaming(responses, output_file, additional_info, word_time_offsets, show_intermediate, file_mode)
#     195 start_time = time.time()  # used in 'time` additional_info
#     196 num_chars_printed = 0  # used in 'no' additional_info
# --> 197 for response in responses:
#     198     if not response.results:
#     199         continue
#
# File c:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\riva\client\asr.py:338, in ASRService.streaming_response_generator(self, audio_chunks, streaming_config)
#     301 """
#     302 Generates speech recognition responses for fragments of speech audio in :param:`audio_chunks`.
#     303 The purpose of the method is to perform speech recognition "online" - as soon as
#    (...)
#     335     <https://docs.nvidia.com/deeplearning/riva/user-guide/docs/reference/protos/protos.html#riva-proto-riva-asr-proto>`_.
#     336 """
#     337 generator = streaming_request_generator(audio_chunks, streaming_config)
# --> 338 for response in self.stub.StreamingRecognize(generator, metadata=self.auth.get_auth_metadata()):
#     339     yield response
#
# File c:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\grpc\_channel.py:541, in _Rendezvous.__next__(self)
#     540 def __next__(self):
# --> 541     return self._next()
#
# File c:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\grpc\_channel.py:967, in _MultiThreadedRendezvous._next(self)
#     965     raise StopIteration()
#     966 elif self._state.code is not None:
# --> 967     raise self
#
# _MultiThreadedRendezvous: <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "WSA Error"
# 	debug_error_string = "UNKNOWN:Error received from peer  {created_time:"2023-08-29T16:46:17.297302656+00:00", grpc_status:14, grpc_message:"WSA Error"}"
# >
