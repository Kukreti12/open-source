# %%
import gradio as gr
import speech_recognition as sr

# Initialize the recognizer
recognizer = sr.Recognizer()

# Define a function to convert audio to text
def audio_to_text(audio_file):
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)
        text = recognizer.recognize_google(audio_data)
    return text

# Create a Gradio interface
iface = gr.Interface(
    fn=audio_to_text,
    inputs=gr.inputs.File(type="file"),
    outputs=gr.outputs.Textbox(),
    live=True,
    title="Audio to Text Conversion",
    description="Upload an audio file and get the text from it.",
)

# Launch the Gradio interface
iface.launch()
# Out:
# C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\deprecation.py:40: UserWarning: `keep_filename` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 241, in __enter__
#     self.audio_reader = wave.open(self.filename_or_fileobject, "rb")
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\wave.py", line 509, in open
#     return Wave_read(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\wave.py", line 163, in __init__
#     self.initfp(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\wave.py", line 128, in initfp
#     self._file = Chunk(file, bigendian = 0)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\chunk.py", line 63, in __init__
#     raise EOFError
# EOFError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 246, in __enter__
#     self.audio_reader = aifc.open(self.filename_or_fileobject, "rb")
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 917, in open
#     return Aifc_read(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 358, in __init__
#     self.initfp(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 314, in initfp
#     chunk = Chunk(file)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\chunk.py", line 63, in __init__
#     raise EOFError
# EOFError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 272, in __enter__
#     self.audio_reader = aifc.open(aiff_file, "rb")
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 917, in open
#     return Aifc_read(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 358, in __init__
#     self.initfp(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 314, in initfp
#     chunk = Chunk(file)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\chunk.py", line 63, in __init__
#     raise EOFError
# EOFError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\routes.py", line 394, in run_predict
#     output = await app.get_blocks().process_api(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\blocks.py", line 1075, in process_api
#     result = await self.call_function(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\blocks.py", line 884, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "C:\Users\sharsaur\AppData\Local\Temp\ipykernel_27616\2346299417.py", line 9, in audio_to_text
#     with sr.AudioFile(audio_file) as source:
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 274, in __enter__
#     raise ValueError("Audio file could not be read as PCM WAV, AIFF/AIFF-C, or Native FLAC; check if file is corrupted or in another format")
# ValueError: Audio file could not be read as PCM WAV, AIFF/AIFF-C, or Native FLAC; check if file is corrupted or in another format
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\routes.py", line 394, in run_predict
#     output = await app.get_blocks().process_api(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\blocks.py", line 1075, in process_api
#     result = await self.call_function(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\blocks.py", line 884, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "C:\Users\sharsaur\AppData\Local\Temp\ipykernel_27616\2346299417.py", line 9, in audio_to_text
#     with sr.AudioFile(audio_file) as source:
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 226, in __init__
#     assert isinstance(filename_or_fileobject, (type(""), type(u""))) or hasattr(filename_or_fileobject, "read"), "Given audio file must be a filename string or a file-like object"
# AssertionError: Given audio file must be a filename string or a file-like object
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 241, in __enter__
#     self.audio_reader = wave.open(self.filename_or_fileobject, "rb")
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\wave.py", line 509, in open
#     return Wave_read(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\wave.py", line 163, in __init__
#     self.initfp(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\wave.py", line 128, in initfp
#     self._file = Chunk(file, bigendian = 0)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\chunk.py", line 63, in __init__
#     raise EOFError
# EOFError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 246, in __enter__
#     self.audio_reader = aifc.open(self.filename_or_fileobject, "rb")
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 917, in open
#     return Aifc_read(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 358, in __init__
#     self.initfp(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 314, in initfp
#     chunk = Chunk(file)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\chunk.py", line 63, in __init__
#     raise EOFError
# EOFError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 272, in __enter__
#     self.audio_reader = aifc.open(aiff_file, "rb")
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 917, in open
#     return Aifc_read(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 358, in __init__
#     self.initfp(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 314, in initfp
#     chunk = Chunk(file)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\chunk.py", line 63, in __init__
#     raise EOFError
# EOFError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\routes.py", line 394, in run_predict
#     output = await app.get_blocks().process_api(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\blocks.py", line 1075, in process_api
#     result = await self.call_function(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\blocks.py", line 884, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "C:\Users\sharsaur\AppData\Local\Temp\ipykernel_27616\2346299417.py", line 9, in audio_to_text
#     with sr.AudioFile(audio_file) as source:
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 274, in __enter__
#     raise ValueError("Audio file could not be read as PCM WAV, AIFF/AIFF-C, or Native FLAC; check if file is corrupted or in another format")
# ValueError: Audio file could not be read as PCM WAV, AIFF/AIFF-C, or Native FLAC; check if file is corrupted or in another format
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 241, in __enter__
#     self.audio_reader = wave.open(self.filename_or_fileobject, "rb")
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\wave.py", line 509, in open
#     return Wave_read(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\wave.py", line 163, in __init__
#     self.initfp(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\wave.py", line 128, in initfp
#     self._file = Chunk(file, bigendian = 0)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\chunk.py", line 63, in __init__
#     raise EOFError
# EOFError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 246, in __enter__
#     self.audio_reader = aifc.open(self.filename_or_fileobject, "rb")
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 917, in open
#     return Aifc_read(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 358, in __init__
#     self.initfp(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 314, in initfp
#     chunk = Chunk(file)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\chunk.py", line 63, in __init__
#     raise EOFError
# EOFError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 272, in __enter__
#     self.audio_reader = aifc.open(aiff_file, "rb")
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 917, in open
#     return Aifc_read(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 358, in __init__
#     self.initfp(f)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\aifc.py", line 314, in initfp
#     chunk = Chunk(file)
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\chunk.py", line 63, in __init__
#     raise EOFError
# EOFError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\routes.py", line 394, in run_predict
#     output = await app.get_blocks().process_api(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\blocks.py", line 1075, in process_api
#     result = await self.call_function(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\blocks.py", line 884, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "C:\Users\sharsaur\AppData\Local\Temp\ipykernel_27616\2346299417.py", line 9, in audio_to_text
#     with sr.AudioFile(audio_file) as source:
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 274, in __enter__
#     raise ValueError("Audio file could not be read as PCM WAV, AIFF/AIFF-C, or Native FLAC; check if file is corrupted or in another format")
# ValueError: Audio file could not be read as PCM WAV, AIFF/AIFF-C, or Native FLAC; check if file is corrupted or in another format
# Traceback (most recent call last):
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\routes.py", line 394, in run_predict
#     output = await app.get_blocks().process_api(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\blocks.py", line 1075, in process_api
#     result = await self.call_function(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\gradio\blocks.py", line 884, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\sharsaur\AppData\Roaming\Python\Python310\site-packages\anyio\_backends\_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "C:\Users\sharsaur\AppData\Local\Temp\ipykernel_27616\2346299417.py", line 9, in audio_to_text
#     with sr.AudioFile(audio_file) as source:
#   File "C:\Users\sharsaur\Anaconda3\envs\riva\lib\site-packages\speech_recognition\__init__.py", line 226, in __init__
#     assert isinstance(filename_or_fileobject, (type(""), type(u""))) or hasattr(filename_or_fileobject, "read"), "Given audio file must be a filename string or a file-like object"
# AssertionError: Given audio file must be a filename string or a file-like object
